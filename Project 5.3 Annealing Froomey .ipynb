# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import copy
from IPython.display import display, Image
from IPython.display import display_pretty, display_html, display_jpeg, display_png, display_json, display_latex, display_svg
from IPython.display import Latex
from IPython.display import HTML
Image(filename='logo3.jpg', width=100)

# %% [markdown]
# # Project 5.3: Aneanling Froomey

# %% [markdown]
# <a href = http://nbviewer.ipython.org/github/by2pie/Bike/blob/master/Project%205.1%20How%20good%20Froomey%20can%20be%20-%20modeling%20and%20understanding%20cycling%20%28creating%20rider%29%20.ipynb> Project 5.1: How good Froomey can be - modeling and understanding cycling (creating rider)</a>
#
# <a href = http://nbviewer.ipython.org/github/by2pie/Bike/blob/master/Project%205.2%20How%20good%20Froomey%20can%20be%20-%20modeling%20cycling%20%28Our%20first%20ride%29.ipynb>Project 5.2 How good Froomey can be - modeling cycling (Our first ride)</a>
#
# <a href = http://nbviewer.ipython.org/github/by2pie/Bike/blob/master/Project%205.3%20Annealing%20Froomey%20.ipynb> Project 5.3 Annealing Froomey</a>
#
# In following notebook I would like to find best strategy for climbing on Mount Ventoux using model developed in previous notebooks.

# %% [markdown]
# ## 1. What we already have, full code:

# %%
global g, cyclists
dt = 10                        #time step
g = 9.8                       #gravitational constant
order_coeff = np.log(2)/4    #slipstream constant     
bar_quant = 100               #number of bar_quants [J]
bar_full = 300/dt * bar_quant #capacity of bar
rho = 1.225                   #density of air
mu = 0.001                    #rolling friction coefficient
basic_air_coeff = 0.3
names = ['Clifford Vetter', 'Michael Colbert', 'Samuel Paine', 'Fidel Marks','Lours Zachmann', 'Clifford Kaufmann', 'Michael Spitzer','Pedro Roth', 'Michael Nork']

class Cyclist():
    
    def __init__(self,energy, mass, area, bars, name,order):
        '''
            Class cyclists with fields 
                - Energy : reservoir of cyclists energy
                - Area : wind area of cyclists
                - Mass : 
                - Order: place in peleton
                - Bars : number of energy bars
                - Speed: Default = 0
                - Distance: Default = 0
                - Name : Random name
                - Data: List of cyclits values during simulation
                - Other variables are not so important
                
        '''
        self.energy = np.round(energy,2)
        self.area = np.round(area,2)
        self.mass = np.round(mass,2)
        self.bars = bars
        self.order = order
        self.name = name
        self.speed = 0
        
        self.air_coef = basic_air_coeff
        self.distance = 0
        self.eated = False
        self.energy_added = 0
        self.maruder = False
        self.data = [[],[],[],[],[]]
    
    def __str__(self):
        return "Hi, my name is "+str(self.name)+" and my skills are as follows: \n Energy = "+str(self.energy)+"\n Mass = "+str(self.mass)+"\n Ares = "+str(self.area)+"\n I will be "+str(self.order)+"th in peleton \n\n"
    
    def set_velocity(self,v):
        '''
            Method setting cyclists speed
        '''
        self.speed = v
        
    def set_order(self,o):
        '''
            Method setting cyclists order in peleton
        '''
        self.order = o
    
    def use_slipstream(self):
        '''
            Calculating changed air_coef using simple model
        '''
        self.air_coef = basic_air_coeff * np.exp(-order_coeff * self.order)
        
    def drink_water(self):
        #to be implemented
        return null
        
    def eat_energy_bar(self):
        if self.bars > 0:
            self.eated = True
            self.bars -= 1
        
#-----------------------------------------------------------------------------------------------------------
#Calculation methods:
    def calc_air_drag(self, rho):
        return self.air_coef * self.area * rho * self.speed**2
    
    def calc_rolling_drag(self, mu):
        return self.mass * g * mu
    
    def calc_incline_drag(self, alpha):
        return self.mass * g * alpha
    
    def calc_power(self,rho, mu, alpha):
        return (self.calc_air_drag(rho) + self.calc_rolling_drag(mu) + self.calc_incline_drag(alpha)) * self.speed
    
#-----------------------------------------------------------------------------------------------------------
    def update(self,rho, mu, alpha, dt):
        '''
            Method updating status of cyclits in each iteration
        '''
        if self.eated:
            self.energy_added += bar_quant * dt
            self.energy += bar_quant * dt
            
            if self.energy_added == bar_full:
                self.eated = False
                self.energy_added = 0
        
        self.use_slipstream()
        self.energy -= self.calc_power(rho, mu, alpha) * dt
        self.distance += self.speed * dt
        self.data[0].append(self.distance)
        self.data[1].append(self.speed)
        self.data[2].append(self.energy)
        self.data[3].append(self.order)
        self.data[4].append(self.calc_power(rho, mu, alpha))    

cyclists = []
Names = []

min_energy = 0.9 * 1e6In following notebook I would like to find best strategy for climbing on Mount Ventoux using model developed in previous notebooks. #[J]
min_mass = 60        #[kg]
min_area = 0.3       #[m^2]
random_factor = 0.2  #possible addon to basic number
bars = 1

#initialization
for i in range(9):
    energy = min_energy * (1 + random_factor*random.random())
    mass = min_mass * (1 + random_factor*random.random())
    area = min_area * (1 + random_factor*random.random())
    bars = 1
    name = names[i]
    cyclists.append(Cyclist(energy, mass, area, bars, name , 0))

#Best strategy seems to have cyclists ordered in increasing energy value:
cyclists.sort(key=lambda x: x.energy, reverse=False)

for i,cycl in enumerate(cyclists):
    cycl.set_order(i)
    print(cycl)
    
mount_ventoux_slope = np.sin(np.arctan(np.array([2.6, 3.6, 4.4, 6.0, 5.9, 4.5, 9.7, 9.6, 10.9, 9.2, 
                      10.1, 9.7, 8.7, 10.4, 8.1, 7.6, 5.9, 7.1, 7.4, 7.9, 9.9]) * 0.01))
flat_slope = np.array([0.0]*21)

#select slope:
global slope
slope = mount_ventoux_slope
#slope = flat_slope

def The_race(speed_plan):
    '''
        Method simulating 21 km race
    '''
    
    global cyclist_team, cyclists
    cyclist_team = copy.deepcopy(cyclists)
    #initialization of variable
    t = 0
    maruders = 0
    change = False

    while cyclist_team[0].distance < 21 * 1e3:
        ''' 
            While first guy covers distance less than 21 km
        '''
        t += dt #time update
        
        ind = int(np.floor(cyclist_team[0].distance/1e3))  #km counter
        
        for i, cycler in enumerate(cyclist_team):
            if not cycler.maruder: #is a rider in a pack? If yes: update
                
                cycler.set_velocity(speed_plan[ind])
                cycler.update(rho, mu, slope[ind], dt)
                if change:
                    cycler.order -= 1
                

                if cycler.energy < 0: #is rider exhausted?
                    cycler.set_order(len(cyclist_team) - 1 - maruders) #take exhausted rider to the end
                    cycler.set_velocity(0.2)  #travel with grupetto speed
                    cycler.maruder = True   #be a maruder
                    change = True
                    maruders +=1
            else:
                cycler.update(rho, mu, mount_ventoux_slope[ind], dt) #if already in grupetto just update
        #sort list with order key
        cyclist_team.sort(key=lambda x: x.order, reverse=False)
        change = False
    print(t)
    return t
        
global cyclist_team
bars_plan = np.random.randint(0, 21, size= 9)  #on wich km should rider take energy_bar
constant_speed = 20   #conatnt speed [km/h]
speed_plan = 1/3.6 *np.array([constant_speed]* 21)

t = The_race(speed_plan)

def ploter():
    fig = plt.figure(facecolor='w')
    ax = plt.subplot(221)
    bx = plt.subplot(222)
    cx = plt.subplot(223)
    dx = plt.subplot(224)
    time = np.linspace(0,t,t/dt)/60
    names_str = []
    la = []
    for cyclist in cyclist_team:
        names_str.append(cyclist.name)
        a,=ax.plot(time,cyclist.data[4])
        la.append(a)
        b,=bx.plot(time,cyclist.data[1])
        c,=cx.plot(time,np.array(cyclist.data[2])/1e3)
        d,=dx.plot(time,cyclist.data[3])
        ax.set_xlabel('Time[min]')
        ax.set_ylabel('Power[W]')
        bx.set_xlabel('Time[min]')
        bx.set_ylabel('Speed[m/s]')
        cx.set_xlabel('Time[min]')
        cx.set_ylabel('Energy[kJ]')
        dx.set_xlabel('Time[min]')
        dx.set_ylabel('Order')
        ax.grid(True)
        bx.grid(True)
        cx.grid(True)
        dx.grid(True)
    plt.legend(la, names_str, loc = 'upper left',fontsize=12 )
    plt.show()
ploter()
# Out:
# Hi, my name is Fidel Marks and my skills are as follows:
#  Energy = 903572.3
#  Mass = 65.76
#  Ares = 0.3
#  I will be 0th in peleton
#
#
# Hi, my name is Michael Spitzer and my skills are as follows:
#  Energy = 929756.35
#  Mass = 61.61
#  Ares = 0.34
#  I will be 1th in peleton
#
#
# Hi, my name is Samuel Paine and my skills are as follows:
#  Energy = 945689.14
#  Mass = 68.58
#  Ares = 0.32
#  I will be 2th in peleton
#
#
# Hi, my name is Michael Colbert and my skills are as follows:
#  Energy = 976657.9
#  Mass = 62.31
#  Ares = 0.34
#  I will be 3th in peleton
#
#
# Hi, my name is Michael Nork and my skills are as follows:
#  Energy = 986464.81
#  Mass = 69.52
#  Ares = 0.34
#  I will be 4th in peleton
#
#
# Hi, my name is Lours Zachmann and my skills are as follows:
#  Energy = 1001391.34
#  Mass = 64.11
#  Ares = 0.33
#  I will be 5th in peleton
#
#
# Hi, my name is Clifford Kaufmann and my skills are as follows:
#  Energy = 1015660.51
#  Mass = 67.7
#  Ares = 0.33
# ...

# %% [markdown]
# ## 2. Pre - optimization

# %% [markdown]
# To optimize I would like to use heuristic method. Previously I wanted to use simulated annealing, but it is for some reason "deprecated" in Scipy so we should stick to some other heuristic method, namely Basin-hopping. This method is strongly connected with perturbations, which means we should think of appropriate initial point. I would like to suggest formula for initial speed vector (21 values for each km) in a following form:

# %% [markdown]
# $$v_i = 50 [km/h] - Grad_i^{1.5}$$

# %%
#Namely:
speed_plan = np.array((50-slope**1.5*100**1.5)/3.6)   #[m/s]
print(speed_plan)
# Out:
# [ 12.72493062  11.99336444  11.3288502    9.81739408   9.91840305
#   11.24125853   5.55582482   5.68317721   3.98079382   6.18634927
#    5.04030619   5.55582482   6.80094484   4.64736847   7.51660739
#    8.09404239   9.91840305   8.6535212    8.32002892   7.74969104
#    5.29927893]

# %% [markdown]
# This ad hoc speed plan gives us following result:

# %%
t = The_race(speed_plan)
ploter()
print('Time needed = '+str(round(t/60,2))+'min')
# Out:
# 2950
# Time needed = 49.17min

# %%
Image(filename='ad_hoc.png', width=1000)

# %% [markdown]
# ## 3. Optimization effect

# %% [markdown]
# To obtain more accurate plan I am using built-in algorithm, already mentioned basin-hopping.

# %%
from scipy import optimize

np.random.seed(555)   # Seeded to allow replication.
res = optimize.basinhopping(The_race, speed_plan)
# Out:
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2950
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 2960
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 3040
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2990
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2920
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2870
# 2900
# 2900
# 2900
# 2900
# ...

# %% [markdown]
# Optimization data:

# %%
res
# Out:
#                    nit: 100
#                   nfev: 2323
#                      x: array([ 13.47099421,  12.54186982,  11.80746773,  10.66140625,
#         11.09510052,   9.60547801,   7.99536473,  10.39870907,
#          7.82324088,   8.11368621,   9.232346  ,   6.86426035,
#          9.44412427,   7.06505163,  11.51130991,  10.59282884,
#         10.29119231,  10.96091794,   8.45340466,  10.92489633,   6.18144122])
#                   njev: 101
#  minimization_failures: 0
#                message: ['requested number of basinhopping iterations completed successfully']
#                    fun: 2240

# %%
t = The_race(res.x)
ploter()
print('Time needed = '+str(round(t/60,2))+'min')
# Out:
# 2240
# Time needed = 37.33min

# %%
Image(filename='optimized.png', width=1000)

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# - It seems like I almost succeed in building accurate model of cycling
# - Resulting numbers, especially power are a little bit overestimated, but it seems to be a question of adjusting initial parameters
# - Optimization worked wonderfully, cutting the time of climb from 49min to 37min, with means a gain of approximately 1/4
# - Some time consuming method of identifying parameters like initial energy reservoir, air resistance coefficient and model of slipstream is strongly recommended

# %% [markdown]
# ## 6. Whats next?

# %% [markdown]
# Next time I would like to either concentrate on something phisical (quantization by deformation for example) or play real world transport tycoon. For sure I can conclude it is going to be continued..

# %% [markdown]
# <a href = http://nbviewer.ipython.org/github/by2pie/Bike/blob/master/Project%205.1%20How%20good%20Froomey%20can%20be%20-%20modeling%20and%20understanding%20cycling%20%28creating%20rider%29%20.ipynb> Project 5.1: How good Froomey can be - modeling and understanding cycling (creating rider)</a>
#
# <a href = http://nbviewer.ipython.org/github/by2pie/Bike/blob/master/Project%205.2%20How%20good%20Froomey%20can%20be%20-%20modeling%20cycling%20%28Our%20first%20ride%29.ipynb>Project 5.2 How good Froomey can be - modeling cycling (Our first ride)</a>
#
# <a href = http://nbviewer.ipython.org/github/by2pie/Bike/blob/master/Project%205.3%20Annealing%20Froomey%20.ipynb> Project 5.3 Annealing Froomey</a>

# %%
HTML('<iframe src=http://by2pie.wordpress.com width=900 height=500></iframe>')
# Out:
# <iframe src=http://by2pie.wordpress.com width=900 height=500></iframe>
